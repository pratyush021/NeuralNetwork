# %% [markdown]
# <a href="https://colab.research.google.com/github/pratyush021/NeuralNetwork/blob/master/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression using neural net

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
n_pts = 100
x = np.linspace(0,10,n_pts)

y = np.sin(x) +np.random.uniform(-0.5,5,n_pts)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# <h2>Importing neural network libraries and utilities below </h2>

# %%
import keras 
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import adam

# %%
model = Sequential()
model.add(Dense(units = 1 , input_dim = 1, activation = 'linear'))
model.compile(adam(lr = 0.1), loss = 'mse',metrics = ['mae'])

# %%
print(model.summary())

# %%
h = model.fit(x,y,epochs = 100, verbose = 1)

# %%
plt.plot(x,model.predict(x),color = 'r')
plt.scatter(x,y)
plt.show()
